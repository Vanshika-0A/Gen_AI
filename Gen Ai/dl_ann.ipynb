# %%
import numpy as np

# %%
x= np.array([[1,0,1,0],[1,0,1,1],[0,1,0,1]])
y = np.array([[1], [1], [0]])

# %%
def sigmoid_activation(x):
    return 1/(1 + np.exp(-x))

# %%
input_neurons = x.shape[1]
hidden_neurons = 3
output_neurons = 1
